# %%
print("Hello World!")

# %%
help(print)

# %%
print('"Hi" fg')
# Out:
# "Hi" fg

# %%
print('''
sdf
gf''')
# Out:
# sdf
# gf

# %%
print((type('10')))
# Out:
# <class 'str'>

# %%
print(print())
# Out:
# None

# %%
print(print('dsfza'))
# Out:
# dsfza
# None

# %%
print("Hi""hb")
# Out:
# Hihb

# %%
print("Hi","hb")
# Out:
# Hi hb

# %%
print("Hi"+"hb")
# Out:
# Hihb

# %%
print("Hi","hb",sep=",")
# Out:
# Hi,hb

# %%
a_2 = 5
print(a_2)
# Out:
# 5

# %%
print('keywords')
# Out:
# keywords

# %%
print("keywords")
# Out:
# keywords

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
print(a)
# Out:
# 5

# %%
a=1+2j
print(a)
print(type(a))
# Out:
# (1+2j)
# <class 'complex'>

# %%
print('hi')
# Out:
# hi

# %%
print('hi')
print(10)
print('abc)
# Out:
#   File "<ipython-input-21-0d292533673b>", line 3
#     print('abc)
#                ^
# SyntaxError: EOL while scanning string literal

# %%
a=[1,2,3]
print(a)
print(type(a))
a=(1,23,2)
print(a)
print(type(a))
a={1,2,3}
print(a)
print(type(a))
a={'1':2}
print(a)
print(type(a))
# Out:
# [1, 2, 3]
# <class 'list'>
# (1, 23, 2)
# <class 'tuple'>
# {1, 2, 3}
# <class 'set'>
# {'1': 2}
# <class 'dict'>

# %%
a=5
b=7.5
c=a+b

# %%
a=5
b=7.5
c=a+b
print(a+b)
print(c)
print(type(c))
# Out:
# 12.5
# 12.5
# <class 'float'>

# %%
a=5
b=int('7')
c=str(a)+str(b)
print(a+b)
print(c)
print(type(c))
# Out:
# 12
# 57
# <class 'str'>

# %%
a=5
b=int('7.5')
c=str(a)+str(b)
print(a+b)
print(c)
print(type(c))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-f2a371445cf9> in <module>
#       1 a=5
# ----> 2 b=int('7.5')
#       3 c=str(a)+str(b)
#       4 print(a+b)
#       5 print(c)
#
# ValueError: invalid literal for int() with base 10: '7.5'

# %%
b=5
print(bool(b))
# Out:
# True

# %%
b=False
print(bool(b))
# Out:
# False

# %%
b=0
print(bool(b))
# Out:
# False

# %%
b=''
print(bool(b))
# Out:
# False

# %%
b=None
print(bool(b))
# Out:
# False

# %%
b="False"
print(bool(b))
# Out:
# True

# %%
b=""
print(bool(b))

# %%
a=6
b=3
print(a/b)
# Out:
# 2.0

# %%
a=True+True
print(a)
# Out:
# 2

# %%
print(type(4/False))

# %%
print(False)
# Out:
# False

# %%
print(0)
# Out:
# 0

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(4))
# Out:
# True

# %%
print(bool(-2))
# Out:
# True

# %%
print(bool(-3))
# Out:
# True

# %%
a=1
a++
print(a)
# Out:
#   File "<ipython-input-57-acf2fd1da449>", line 2
#     a++
#        ^
# SyntaxError: invalid syntax

# %%
print(1 and 1)
# Out:
# 1

# %%
print(5 and 0)
# Out:
# 0

# %%
0 and ''
# Out:
# 0

# %%
1 and 4
# Out:
# 4

# %%
None and None

# %%
False and None
# Out:
# False

# %%
print(None and None)
# Out:
# None

# %%
type(and)
# Out:
#   File "<ipython-input-66-5d36ea62b089>", line 1
#     type(and)
#          ^
# SyntaxError: invalid syntax

# %%
help(and)
# Out:
#   File "<ipython-input-67-2d1f0e31d4a9>", line 1
#     help(and)
#          ^
# SyntaxError: invalid syntax

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
help(False
)

# %%
7//2
# Out:
# 3

# %%
a=3
print(a=+3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ffb66bafd00d> in <module>
#       1 a=3
# ----> 2 print(a=+3)
#
# TypeError: 'a' is an invalid keyword argument for print()

# %%
'1' in 123
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-a98a41fd2b41> in <module>
# ----> 1 '1' in 123
#
# TypeError: argument of type 'int' is not iterable

# %%
1 in '123'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-d40b0b62e090> in <module>
# ----> 1 1 in '123'
#
# TypeError: 'in <string>' requires string as left operand, not int

# %%
True in 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-1078f40f4d29> in <module>
# ----> 1 True in 1
#
# TypeError: argument of type 'int' is not iterable

# %%
1 in 123
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c882fe0fbc65> in <module>
# ----> 1 1 in 123
#
# TypeError: argument of type 'int' is not iterable

# %%
1 is 1
1 is 1.0
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-5-67bb75501f0b>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   1 is 1
# <ipython-input-5-67bb75501f0b>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   1 is 1.0
# False

# %%
1 is 1
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-6-c4ba21148a2b>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   1 is 1
# True

# %%
1 is 1.0
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-7-2ebf4c947f31>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   1 is 1.0
# False

# %%
1 in 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ca0393ac6151> in <module>
# ----> 1 1 in 1
#
# TypeError: argument of type 'int' is not iterable

# %%
1.0 in 1.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c4131d7aeacf> in <module>
# ----> 1 1.0 in 1.0
#
# TypeError: argument of type 'float' is not iterable

# %%
1 == 1.0
# Out:
# True

# %%
2^3
# Out:
# 1

# %%
3^2
# Out:
# 1

# %%
1 & 1
1 & 0
0 & 0
0 & 1
# Out:
# 0

# %%
5^3
# Out:
# 6

# %%
5|3
# Out:
# 7

# %%
5>>2
# Out:
# 1

# %%
5<<2
# Out:
# 20

# %%
6<<2
# Out:
# 24

# %%
5<<1
# Out:
# 10

# %%
5<<0
# Out:
# 5

# %%
5<<-1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-c3ea30eee4d9> in <module>
# ----> 1 5<<-1
#
# ValueError: negative shift count

# %%
-1<<2
# Out:
# -4

# %%
~5
# Out:
# -6

# %%
~0
# Out:
# -1

# %%
~-1
# Out:
# 0

# %%
~-6
# Out:
# 5

# %%
2^125
# Out:
# 127

# %%
2**125
# Out:
# 42535295865117307932921825928971026432

# %%
2**5**3
# Out:
# 42535295865117307932921825928971026432

# %%
2**5**3 == 2**125
# Out:
# True

# %%
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f84ab820532c> in <module>
# ----> 1 pi
#
# NameError: name 'pi' is not defined

# %%
('v' in 'vishal') or ((train in 'vishal'))
# Out:
# True

# %%
7 + 3**2**5 + 3 - False/True
# Out:
# 1853020188851851.0

# %%
5+7 and ""
# Out:
# ''

# %%
if 1==1:
    print("hi")
# Out:
# hi

# %%
(train in 'vishal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-774c89c04b92> in <module>
# ----> 1 (train in 'vishal')
#
# NameError: name 'train' is not defined

# %%
True or train in 'vishal'
# Out:
# True

# %%
if 1==1:
print("hi")
# Out:
#   File "<ipython-input-39-72d2f22dfd74>", line 2
#     print("hi")
#     ^
# IndentationError: expected an indented block

# %%
if 1==1
    print("hi")
# Out:
#   File "<ipython-input-40-8a220cdb0a84>", line 1
#     if 1==1
#            ^
# SyntaxError: invalid syntax

# %%
if 1==1:
    
print("hi")
# Out:
#   File "<ipython-input-41-4add8669d507>", line 3
#     print("hi")
#     ^
# IndentationError: expected an indented block

# %%
if 1==1:
    print("hi")
# Out:
# hi

# %%
a = int(input("Enter n : "))
# Out:
# Enter n : 2

# %%
a = (input("Enter n : "))
print(a)
print(type(a))
# Out:
# Enter n : sd
# sd
# <class 'str'>

# %%
a = int(input("Enter n : "))
if(a==1):
    print("hi")
print(a)
print(type(a))
# Out:
# Enter n : 1
# hi
# 1
# <class 'int'>

# %%
a = int(input("Enter n : "))
if a%2==1:
    print("odd")
else:
    print("even")
print(a)
# Out:
# Enter n : dzc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-ebf4edf3bc03> in <module>
# ----> 1 a = int(input("Enter n : "))
#       2 if a%2==1:
#       3     print("odd")
#       4 else:
#       5     print("even")
#
# ValueError: invalid literal for int() with base 10: 'dzc'

# %%
try:
    a = int(input("Enter n : "))
except ValueError:
    print("g")
if a%2==1:
    print("odd")
else:
    print("even")
print(a)
# Out:
# Enter n : fs
# g
# odd
# 2345

# %%
try:
    n = int(input("Enter n : "))
except ValueError:
    print("g")
if n%2==1:
    print("odd")
else:
    print("even")
print(n)
# Out:
# Enter n : fd
# g
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9a2325b35d1a> in <module>
#       3 except ValueError:
#       4     print("g")
# ----> 5 if n%2==1:
#       6     print("odd")
#       7 else:
#
# NameError: name 'n' is not defined

# %%
try:
    a = int(input("Enter n : "))
except ValueError:
    print("g")
if a%2==1:
    print(f"{a} is odd")
else:
    print(f"{a} is even")
print(a)
# Out:
# Enter n : fsa
# g
# 34 is even
# 34

# %%
print(a, "is")
# Out:
# 34 is

# %%
try:
    a = int(input("Enter n : "))
except ValueError:
    print("TypeError")
    
# Most common method
'''
if a%4==0:
    if a%100==0:
        if a%400==0:
            print(f"{a} is leap year")
        else:
            print(f"{a} is not leap year")
    else:
        print(f"{a} is leap year")
else:
    print(f"{a} is not leap year")
'''


# if a%4!=0:
#     print(f"{a} is not leap year")
# else:
#     if a%100== 0  and a%400!=0:
#         print(f"{a} is not leap year")
#     else:
#         print(f"{a} is leap year")
        
if (a%4==0 and a%100!=0) or a%400==0:
    print(f"{a} is leap year")
else:
    print(f"{a} is not leap year")
# Out:
# Enter n : 1900
# 1900 is not leap year

# %%
panny=1
fives=5
tens=10
quarter=25
Nickle=75
a = int(input("Enter n : "))
x=""
if a>=75:
    z=a//75
    print(f" {z} Nickle",end = "")
    a=a%75
if a>=25:
    z=a//25
    print(f" {z} quarter",end = "")
    a=a%25
if a>=10:
    z=a//10
    print(f" {z} tens",end = "")
    a=a%10
if a>=5:
    z=a//5
    print(f" {z} fives",end = "")
    a=a%5
if a>0:
    print(f" {a} panny",end = "")
# Out:
# Enter n : 200
#  2 Nickle 2 quarter

# %%
year = int(input("Enter year : "))
a=True
if year>0:
    month = int(input("Enter month : "))
    if month>0 and month<=12:
        date = int(input("Enter date : "))
        if(date>0 and date<=31):
            if(month==1 or month==3 or month==5 or month==7 or month==8 or month==10 or month==12):
                if(date==31):
                    date=1
                    if(month==12):
                        month=1
                        year+=1
                    else:
                        month+=1
                else:
                    date+=1
            elif(month==2):
                if (a%4==0 and a%100!=0) or a%400==0:
                    if(date>29):
                        a=False
                        print("Invalid date")
                    elif date==29:
                        date=1
                        month=3
                    else:
                        date+=1
                else:
                    if(date>28):
                        a=False
                        print("Invalid date")
                    elif date==28:
                        date=1
                        month=3
                    else:
                        date+=1
            else:
                if(date==31):
                    a=False
                    print("Invalid date")
                elif(date==30):
                    date=1
                    month+=1
                else:
                    date+=1
            if(a):
                print(f"{date} {month} {year}")
        else:
            print("Invalid Date")
    else:
        print("Invalid Month")
else:
    print("Invalid Year")
# Out:
# Enter year : 1452-2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-136cb218b7ac> in <module>
# ----> 1 year = int(input("Enter year : "))
#       2 a=True
#       3 if year>0:
#       4     month = int(input("Enter month : "))
#       5     if month>0 and month<=12:
#
# ValueError: invalid literal for int() with base 10: '1452-2'

# %%
cm = int(input("Enter cm: "))
km=cm//10000000
cm=cm%10000000
m=m//100

# %%
print("hi" if 1==1 else "hi")
# Out:
# hi

# %%
print("ho" if 1==1 else "hi")
# Out:
# ho

# %%
print(a,"afd")
# Out:
# 1900 afd

# %%
print(f"{a} afd")
# Out:
# 1900 afd
