# %%
from datetime import date,time,datetime

# %%
print(date.today())
# Out:
# 2025-12-02

# %%
x=date(2025,11,2)
print(x)
y=time(8,10,2)
print(y)
print(datetime.now())
# Out:
# 2025-11-02
# 08:10:02
# 2025-12-02 11:46:26.754146

# %%
import os

# %%
pwd
# Out:
# 'D:\\yuvraj'

# %%
os.getcwd() #Current working directory
# Out:
# 'D:\\'

# %%
os.chdir("..")# go to parent directory(by writing "..") or change directory(by writing addres in "")
os.getcwd()
# Out:
# 'D:\\'

# %%
os.mkdir("D:/VHA")

# %%
os.mkdir("D:/VHA/VHA10")

# %%
os.getcwd()
# Out:
# 'D:\\'

# %%
os.chdir("D:/VHA")
os.getcwd()
# Out:
# 'D:\\VHA'

# %%
os.listdir()
# Out:
# ['VHA10']

# %%
os.listdir("C:")
# Out:
# ['!qhlogs.doc',
#  '$Recycle.Bin',
#  '$WinREAgent',
#  'bootTel.dat',
#  'cfrbackup-WZITMJTO',
#  'DEMO',
#  'Documents and Settings',
#  'DumpStack.log',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'inetpub',
#  'Insight Files',
#  'Intel',
#  'logs',
#  'msdia80.dll',
#  'MSOCache',
#  'oraclexe',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Recovery',
#  'RESULT',
#  'swapfile.sys',
#  'System Volume Information',
#  'TurboC++',
#  'Users',
#  'Windows',
#  'xampp']

# %%
print(os.listdir("D:"))
print(os.listdir("D:/VHA"))
# Out:
# ['.ipynb_checkpoints', '1.txt', '2.txt', '3.txt', 'city.txt', 'example.txt', 'example1.txt', 'example2.txt', 'example3.txt', 'Example4.txt', 'file3.txt', 'file_practice.ipynb', 'friends.txt', 'Friends2.txt', 'logfile.txt', 'mbox-short.txt', 'namelist.txt', 'python.txt', 'python1.txt', 'python2.txt', 'QB_SOLUTION_6,7,8-Copy1 (1).ipynb', 'sample.txt', 'sample1.txt', 'scores.txt', 'secretmessage - Copy.txt', 'secretmessage.txt', 'Story.txt', 'T3_CH_6.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb']
# ['VHA10']

# %%
import os

# %%
os.getcwd()
os.chdir("D:/VHA")
os.getcwd()
# Out:
# 'D:\\VHA'

# %%
f1=open("file1.txt",'w')
f2=open("file2.txt",'w')
f1.write("hello")
f2.write("Welcome")
f1.close()
f2.close()

# %%
os.listdir("D:/VHA")
# Out:
# ['file1.txt', 'file2.txt', 'VHA10']

# %%
os.remove("D:/VHA/file1.txt")

# %%
os.rmdir("D:/VHA")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-16-79796abdbd91> in <module>
# ----> 1 os.rmdir("D:/VHA")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'D:/VHA'

# %%
os.rmdir("D:/VHA/VHA10")

# %%
os.remove("D:/VHA/file2.txt")

# %%
os.rmdir("D:/VHA")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-21-79796abdbd91> in <module>
# ----> 1 os.rmdir("D:/VHA")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'D:/VHA'

# %%
os.chdir("..")

# %%
os.rmdir("D:/VHA")
