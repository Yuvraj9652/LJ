# %%
import numpy as np

# %%
l=[[1],[2,3],3]
x=np.array(l)
print(x)
y=list(x)
print(y)
np.shape(x)
# Out:
# [list([1]) list([2, 3]) 3]
# [[1], [2, 3], 3]
# <ipython-input-10-9a1b034484b5>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x=np.array(l)
# (3,)

# %%
np.sort(x,axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4d768624a74d> in <module>
# ----> 1 np.sort(x,axis=0)
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sort(a, axis, kind, order)
#     989     else:
#     990         a = asanyarray(a).copy(order="K")
# --> 991     a.sort(axis=axis, kind=kind, order=order)
#     992     return a
#     993
#
# TypeError: '<' not supported between instances of 'int' and 'list'

# %%
for i in x:
    print(i)
for i in np.nditer(x):
    print(i)
# Out:
# [1]
# [2, 3]
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-35a96ea80b1c> in <module>
#       1 for i in x:
#       2     print(i)
# ----> 3 for i in np.nditer(x):
#       4     print(i)
#
# TypeError: Iterator operand or requested dtype holds references, but the REFS_OK flag was not enabled

# %%
x1=np.array([1,2,3])
x2=np.array([2,1])
print(np.concatenate((x1,x2)))
# Out:
# [1 2 3 1 2]

# %%
x1=np.array([1,2,3])
x2=np.array([2,1])
print(np.concatenate((x1,x2),axis=1))
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-22-5c96e53e1cf6> in <module>
#       1 x1=np.array([1,2,3])
#       2 x2=np.array([2,1])
# ----> 3 print(np.concatenate((x1,x2),axis=1))
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# AxisError: axis 1 is out of bounds for array of dimension 1
