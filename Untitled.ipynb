# %%
class A:
    x=10
    y=10
    def __init__(self):
        print("Hello")
    def show(self):
        print("Bye")
class B(A):
    x=20
    def __init__(self):
        x=2
        self.x=220
        print('good')
        super().__init__()
    def show(self):
        print("Dhoni")
        super().show()
b=B()
b.show()
a=A()
A.show(a)
print(a.x)
print(b.x)
print(a.y)
print(b.y)
# Out:
# good
# Hello
# Dhoni
# Bye
# Hello
# Bye
# 10
# 220
# 1
# 1

# %%
class A:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        print("hi")
    def show(self):
        print("Bye")
class B(A):
    def __init__(self,d,a,b,c):
        self.d=d
        print('good')
        super().__init__(a,b,c)
    def show(self):
        print(self.a)
        print("Dhoni")
b=B(1,2,3,4)
b.show()
# Out:
# good
# hi
# 2
# Dhoni

# %%
class A(B):
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        print("hi")
    def show(self):
        print("Bye")
class B(A):
    def __init__(self,d,a,b,c):
        self.d=d
        print('good')
        super().__init__(a,b,c)
    def show(self):
        print(self.a)
        print("Dhoni")
b=B(1,2,3,4)
b.show()
# Out:
# good
# hi
# 2
# Dhoni

# %%
class A:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        print("hi")
    def show(self):
        print("Bye")
class B:
    def __init__(self,d,a,b,c):
        self.d=d
        print('good')
    def show(self):
        print("Dhoni")
class D(B,C,A):
    pass
b=B(1,2,3,4)
b.show()
c=C()
d=D(2,1,3,4)
# Out:
# good
# Dhoni
# hi
# good

# %%
class A:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        print("hi")
    def show(self):
        print("Bye")
class B(A):
    def __init__(self,d,a,b,c):
        self.d=d
        print('good')
        super().__init__(a,b,c)
    def show(self):
        print(self.a)
        print("Dhoni")
class D(B,A):
    pass
class C(A,B):
    def __init__(self):
        print("hi")
# class D(B,C,A):
#     pass
b=B(1,2,3,4)
b.show()
c=C()
d=D()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-5e4d199d69cb> in <module>
#      17 class D(B,A):
#      18     pass
# ---> 19 class C(A,B):
#      20     def __init__(self):
#      21         print("hi")
#
# TypeError: Cannot create a consistent method resolution
# order (MRO) for bases A, B

# %%
class A:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        print("hi")
    def show(self):
        print("Bye")
class B(A):
    def __init__(self,d,a,b,c):
        self.d=d
        print('good')
        super().__init__(a,b,c)
    def show(self):
        print(self.a)
        print("Dhoni")
class C(B,A):
    def __init__(self):
        print("hi")
class D(B,C,A):
    pass
b=B(1,2,3,4)
b.show()
c=C()
d=D()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-61e2c32dd809> in <module>
#      18     def __init__(self):
#      19         print("hi")
# ---> 20 class D(B,C,A):
#      21     pass
#      22 b=B(1,2,3,4)
#
# TypeError: Cannot create a consistent method resolution
# order (MRO) for bases B, C, A

# %%
class A:
    pass
class B:
    pass
class C:
    pass
class X(A,B):
    pass
class Y(B,C):
    pass
class P(X,Y,C):
    pass
print(P.mro())
print(P.__mro__)
# Out:
# [<class '__main__.P'>, <class '__main__.X'>, <class '__main__.A'>, <class '__main__.Y'>, <class '__main__.B'>, <class '__main__.C'>, <class 'object'>]
# (<class '__main__.P'>, <class '__main__.X'>, <class '__main__.A'>, <class '__main__.Y'>, <class '__main__.B'>, <class '__main__.C'>, <class 'object'>)

# %%
class A:
    pass
class B:
    pass
class C:
    pass
class D(A,X):
    pass
class X(A,B):
    pass
class Y(B,C):
    pass
class P(X,Y,D):
    pass
print(P.mro())
print(P.__mro__)
# Out:
# [<class '__main__.P'>, <class '__main__.X'>, <class '__main__.Y'>, <class '__main__.D'>, <class '__main__.A'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.X'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>]
# (<class '__main__.P'>, <class '__main__.X'>, <class '__main__.Y'>, <class '__main__.D'>, <class '__main__.A'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.X'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>)

# %%
class A:
    def __init__(self,m):
        self.m=m
    def __add__(self,other):
        "Called when +"
        print("you couuld do anything in this method or any below method conditions are written below")
        return self.m+other.m
    def __sub__(self):
        "called when -"
        pass
    def __mul__(self):
        "*"
        pass
    def __truediv__(self,m):
        '''/'''
        pass
    def __mod__(self,m):
        "%"
        pass
    def __eq__(self,m):
        "=="
        pass
    def __ne__(self,m):
        "!="
        pass
    def __lt__(self,m):
        "<"
        pass
    def __gt__(self,m):
        ">"
        pass
    def __le__(self,m):
        "<="
        pass
    def __ge__(self,m):
        ">="
        pass
    def __str__(self):
        "print"
        return "lol"
a1=A(10)
a2=A(20)
print(a1+a2)
print(a1)
# Out:
# you couuld do anything in this method or any below method conditions are written below
# 30
# lol
