# %%
print 'hello'
# Out:
#   File "<ipython-input-1-5a1ef41e7057>", line 1
#     print 'hello'
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('hello')?

# %%
print "B1 is Best"
# Out:
# 'B1 is Best'

# %%
iff 3>4:
    print("B1 s bvest")
# Out:
#   File "<ipython-input-3-45de60b34a30>", line 1
#     iff 3>4:
#         ^
# SyntaxError: invalid syntax

# %%
for i in range(10):
# Out:
#   File "<ipython-input-4-e61162350cc4>", line 1
#     for i in range(10):
#                        ^
# SyntaxError: unexpected EOF while parsing

# %%
class Vishal:
# Out:
#   File "<ipython-input-5-2f13df65d1c8>", line 1
#     class Vishal:
#                  ^
# SyntaxError: unexpected EOF while parsing

# %%
def f():
# Out:
#   File "<ipython-input-6-2ba2580b0af7>", line 1
#     def f():
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
print("hi
# Out:
#   File "<ipython-input-7-afee0c685f2a>", line 1
#     print("hi
#              ^
# SyntaxError: EOL while scanning string literal

# %%
l=[3,5
# Out:
#   File "<ipython-input-8-9817336d825a>", line 1
#     l=[3,5
#           ^
# SyntaxError: unexpected EOF while parsing

# %%
d={'A':}
# Out:
#   File "<ipython-input-9-fa73476b1acb>", line 1
#     d={'A':}
#            ^
# SyntaxError: invalid syntax

# %%
d={'A':3
# Out:
#   File "<ipython-input-10-a1486d207723>", line 1
#     d={'A':3
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
print(bvgfsuyk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3aecda708fb1> in <module>
# ----> 1 print(bvgfsuyk)
#
# NameError: name 'bvgfsuyk' is not defined

# %%
fjbdmks
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-15aad9378832> in <module>
# ----> 1 fjbdmks
#
# NameError: name 'fjbdmks' is not defined

# %%
3+"3"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-513d302b33cc> in <module>
# ----> 1 3+"3"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
int("bdfshvc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-77519963355a> in <module>
# ----> 1 int("bdfshvc")
#
# ValueError: invalid literal for int() with base 10: 'bdfshvc'

# %%
if 3>4:
print("hi")
# Out:
#   File "<ipython-input-15-926818b870dc>", line 2
#     print("hi")
#     ^
# IndentationError: expected an indented block

# %%
l=[1]
print(l[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-8c17afcfe101> in <module>
#       1 l=[1]
# ----> 2 print(l[2])
#
# IndexError: list index out of range

# %%
l=[1]
l.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-80b6fdb59fc6> in <module>
#       1 l=[1]
# ----> 2 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
d={[jbdas]:1}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-8873bd93990f> in <module>
# ----> 1 d={[jbdas]:1}
#
# NameError: name 'jbdas' is not defined

# %%
d={}
d['A']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-d91c7aa8858c> in <module>
#       1 d={}
# ----> 2 d['A']
#
# KeyError: 'A'

# %%
f=open("VHA.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-e76abeef4c53> in <module>
# ----> 1 f=open("VHA.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'VHA.txt'

# %%
import VHA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-aa5eb2efb400> in <module>
# ----> 1 import VHA
#
# ModuleNotFoundError: No module named 'VHA'

# %%
print(2/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-22-d2c0889640ff> in <module>
# ----> 1 print(2/0)
#
# ZeroDivisionError: division by zero

# %%
print('2'/0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-7471ef24d4a3> in <module>
# ----> 1 print('2'/0)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# ### Error always in Pascal(1st letter capital and other words also capital)
