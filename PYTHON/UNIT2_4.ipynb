# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\LJENG\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df=pd.read_csv("PANDAS_DATA/movies.csv")
df
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
df.groupby("imdb_rating").agg({"imdb_rating":"max"})
# Out:
#             imdb_rating
#                     max   sum
# imdb_rating
# 0.0                 0.0   0.0
# 1.5                 1.5   3.0
# 1.7                 1.7   6.8
# 1.8                 1.8   1.8
# 1.9                 1.9   5.7
# ...                 ...   ...
# 8.6                 8.6   8.6
# 8.7                 8.7  17.4
# 8.9                 8.9   8.9
# 9.0                 9.0   9.0
# 9.4                 9.4   9.4
#
# [76 rows x 2 columns]

# %%
df.groupby("genres")["imdb_rating"].mean().sort_values()
# Out:
# genres
# Biography|History          0.0
# Drama|Short                0.0
# Comedy|Family|Sci-Fi       2.4
# Action|Crime|Romance       2.4
# Action|Fantasy|Sci-Fi      2.6
#                           ...
# Adventure|Drama|Musical    8.1
# Drama|Short|Thriller       8.2
# Drama|Fantasy|Horror       8.2
# Documentary|War            8.3
# Documentary|Sport          8.6
# Name: imdb_rating, Length: 205, dtype: float64

# %%
x=df.groupby("genres")["imdb_rating"].mean().sort_values()
#Print movie name with highest imdb in genre
# Out:
# ('Action', 78      3.0
# 176     2.9
# 367     7.1
# 368     7.1
# 435     5.4
# 452     3.7
# 535     4.2
# 538     5.7
# 637     5.1
# 1146    5.1
# 1171    6.3
# 1310    5.0
# 1411    3.3
# 1585    5.0
# 1627    7.4
# Name: imdb_rating, dtype: float64)
# ('Action|Adventure', 24     5.3
# 166    4.0
# 756    4.0
# Name: imdb_rating, dtype: float64)
# ('Action|Adventure|Animation', 685    6.8
# 706    6.3
# 903    4.2
# Name: imdb_rating, dtype: float64)
# ('Action|Adventure|Comedy', 13      4.3
# 203     6.4
# 314     5.1
# 321     3.2
# 537     5.5
# 598     6.6
# 789     1.7
# 1029    5.6
# 1044    1.7
# 1067    7.2
# 1070    4.5
# Name: imdb_rating, dtype: float64)
# ('Action|Adventure|Crime', 928    3.5
# Name: imdb_rating, dtype: float64)
# ('Action|Adventure|Drama', 34      5.7
# 198     4.1
# 318     5.7
# 355     4.6
# 821     4.6
# 858     5.4
# 905     3.4
# 944     4.8
# 1009    2.6
# 1011    3.4
# 1302    6.0
# 1330    3.4
# 1398    5.2
# ...

# %%
#PRINT HIGHEST IMDB RATING IN GROUPED GENRE
