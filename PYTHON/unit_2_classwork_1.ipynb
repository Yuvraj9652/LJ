# %% [markdown]
# # 1.You are given marks of 12 students in 5 subjects: Math, Physics, Chemistry, Biology, and English.
#
# 1. Create a DataFrame df_scores with random integer values between 40 and 100.
#
# 2. Analyze the relationship between all subjects.
#
# 3. Visualize the relationships using a heatmap such that:
#
# The color scale is centered properly for negative to positive relationships
#
# Strong positive and negative relationships are clearly distinguishable using contrasting colors
#
# Each cell is clearly separated by visible borders
#
# The exact numeric relationship values are displayed inside each cell
#
# A legend for colors is visible

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(42)

df_scores = pd.DataFrame({
    "Math": np.random.randint(40, 100, 12),
    "Physics": np.random.randint(40, 100, 12),
    "Chemistry": np.random.randint(40, 100, 12),
    "Biology": np.random.randint(40, 100, 12),
    "English": np.random.randint(40, 100, 12)
})
sns.heatmap(df_scores.corr(numeric_only=True),vmin=-1,vmax=1,linecolor="red",linewidths=2,annot=True,)
# Out:
# <Axes: >

# %% [markdown]
# # 2. You are given employee salary data across multiple departments. Each department has both male and female employees.
#
# 1. Create a DataFrame df_employee with:
#
# Departments: IT, HR, Finance, Marketing
#
# Gender: Male / Female
#
# Salary: random realistic salary values
#
# 2. Visualize the salary distribution such that:
#
# Each department is shown separately along one axis
#
# Salary spread is clearly visible using quartiles and medians
#
# Within each department, comparison between male and female employees is clearly distinguishable
#
# All distributions share the same visual tone (single consistent color)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(42)

df_employee = pd.DataFrame({
    "Department": np.random.choice(["IT", "HR", "Finance", "Marketing"], 40),
    "Gender": np.random.choice(["Male", "Female"], 40),
    "Salary": np.random.randint(30000, 100000, 40)
})

sns.boxplot(data=df_employee,x="Department",y="Salary",hue="Gender",color="red")
# Out:
# C:\Users\VISHAL\AppData\Local\Temp\ipykernel_8188\1134191859.py:14: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.boxplot(data=df_employee,x="Department",y="Salary",hue="Gender",color="red")
# <Axes: xlabel='Department', ylabel='Salary'>

# %% [markdown]
# # 3. You are given student performance data.
#
# Tasks:
#
# 1. Create a DataFrame df_performance with:
#
# Number of hours studied
#
# Marks obtained
#
# Gender of student
#
# Section (A, B, C)
#
# 2. Visualize the relationship such that:
#
# Study time is placed along the horizontal direction
#
# Marks are represented vertically
#
# Male and female students are distinguished using different colors
#
# Students from different sections are represented using different marker shapes
#
# All data points are clearly visible and slightly larger than default size

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_performance = pd.DataFrame({
    "Hours_Studied": [2, 3, 4, 5, 6, 7, 8, 2.5, 3.5, 6.5, 7.5, 5.5],
    "Marks": [40, 50, 55, 65, 70, 80, 90, 45, 52, 75, 85, 68],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female",
               "Male", "Female", "Male", "Female", "Male", "Female"],
    "Section": ["A", "A", "B", "B", "C", "C",
                "A", "B", "C", "A", "B", "C"]
})

sns.scatterplot(data=df_performance,x="Hours_Studied",y="Marks",hue="Gender",style="Section",s=70)
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Marks'>

# %% [markdown]
# # 4. you are given order data across different cities and product categories.
#
# 1. Create a DataFrame df_orders containing:
#
# City names
#
# Product categories
#
# Number of orders
#
# 2. Visualize the data such that:
#
# Each city is represented along the horizontal direction
#
# Order counts are shown vertically
#
# Different product categories are distinguished using colors
#
# Bars belonging to the same city appear side-by-side (not stacked)
#
# Each bar also has a unique pattern style based on category
#
# Exact order values are displayed on the bars
#
# When hovering, additional category information is visible
#
# The chart has a proper title and a wider rectangular layout
#
# Use a fixed set of three distinct colors

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
df_orders = pd.DataFrame({
    "City": ["Ahmedabad", "Ahmedabad", "Ahmedabad",
             "Mumbai", "Mumbai", "Mumbai",
             "Delhi", "Delhi", "Delhi"],
    "Category": ["Electronics", "Clothing", "Grocery",
                 "Electronics", "Clothing", "Grocery",
                 "Electronics", "Clothing", "Grocery"],
    "Orders": [120, 90, 150, 200, 140, 180, 170, 110, 160]
})
px.bar(data_frame=df_orders,x="City",y="Orders",color= "Category",barmode="group",
        text_auto=True,hover_data=[ "Category"],pattern_shape= "Category",
       color_discrete_sequence=["red","green","blue"])

# %% [markdown]
# # 5. You are analyzing how advertising impacts revenue across different regions.
#
# 1. Create a DataFrame df_sales with:
#
# Advertising investment
#
# Revenue generated
#
# Region (North, South, East)
#
# Profit earned
#
# 2. Build a visualization such that:
#
# Advertising spend is shown along the horizontal direction
#
# Revenue is represented vertically
#
# Each region is distinguished using different colors and marker shapes
#
# The size of each point reflects profitability
#
# The chart is split into multiple panels, one for each region
#
# The layout is wide and clearly visible

# %%
import pandas as pd
import plotly.express as px

df_sales = pd.DataFrame({
    "Advertising_Spend": [1000, 1500, 2000, 1200, 1800, 2200, 1300, 1700, 2100],
    "Revenue": [5000, 7000, 9000, 5500, 7500, 9500, 6000, 8000, 10000],
    "Region": ["North", "North", "North",
               "South", "South", "South",
               "East", "East", "East"],
    "Profit": [500, 800, 1200, 600, 900, 1300, 550, 850, 1250]
})
px.scatter(data_frame=df_sales,x="Advertising_Spend",y="Revenue",color="Region",size="Profit",
          symbol="Region",facet_col="Region")

# %% [markdown]
# # 6. You are given spatial data representing objects in a 3D environment.
#
# Tasks:
#
# 1. Create a DataFrame df_space containing:
#
# Three-dimensional coordinates of objects
#
# A category/type for each object
#
# A value indicating intensity or strength
#
# 2. Visualize the data such that:
#
# Points are positioned across three axes (depth included)
#
# Different object types are distinguished using colors
#
# Points vary in size depending on their intensity
#
# The chart has a clear descriptive heading

# %%
import pandas as pd
import plotly.express as px


df_space = pd.DataFrame({
    "X": [1, 2, 3, 4, 5, 6],
    "Y": [2, 3, 4, 5, 6, 7],
    "Z": [3, 1, 5, 2, 6, 4],
    "Type": ["A", "B", "A", "B", "C", "C"],
    "Magnitude": [10, 20, 15, 25, 18, 30]
})

px.scatter_3d(data_frame=df_space,x="X",y="Y",z="Z",color="Type",size="Magnitude")

# %% [markdown]
# # 7. You are analyzing health-related measurements of individuals.
#
#  Tasks:
#
# 1. Create a DataFrame df_health with:
#
# Physical attributes (height, weight, BMI, age)
#
# A label indicating whether a person is Fit or Unfit
#
# 2. Build a visualization such that:
#
# All numerical attributes are compared pairwise in a grid format
#
# Each small plot shows the relationship between two variables
#
# Individuals are distinguished based on fitness category using colors
#
# The entire visualization is large and clearly readable (square layout)

# %%
import pandas as pd
import plotly.express as px


df_health = pd.DataFrame({
    "Height": [160, 165, 170, 175, 180, 155, 168, 172],
    "Weight": [55, 65, 70, 75, 85, 50, 68, 72],
    "BMI": [21.5, 23.9, 24.2, 24.5, 26.2, 20.8, 24.1, 24.3],
    "Age": [22, 25, 30, 28, 35, 24, 27, 29],
    "Category": ["Fit", "Fit", "Unfit", "Unfit", "Unfit", "Fit", "Fit", "Unfit"]
})

px.scatter_matrix(data_frame=df_health,dimensions=["Height", "Weight",   "BMI"  ,"Age" ],color="Category")

# %% [markdown]
# # 8. You are given temperature data for multiple cities over several days.
#
# Tasks:
#
# 1. Create a DataFrame df_weather containing:
#
# Days (Day 1 to Day 7)
#
# City names
#
# Temperature values
#
# 2. Visualize the data such that:
#
# Time progression is shown along the horizontal direction
#
# Temperature changes are displayed vertically
#
# Each city is represented by a separate colored line
#
# Data points on the lines are clearly marked
#
# When hovering, city information is visible
#
# The chart includes a clear descriptive heading
#
# Use a fixed set of three distinct colors

# %%
import pandas as pd
import plotly.express as px

df_weather = pd.DataFrame({
    "Day": ["Day1","Day2","Day3","Day4","Day5","Day6","Day7",
            "Day1","Day2","Day3","Day4","Day5","Day6","Day7",
            "Day1","Day2","Day3","Day4","Day5","Day6","Day7"],
    "City": ["Ahmedabad"]*7 + ["Mumbai"]*7 + ["Delhi"]*7,
    "Temperature": [
        30, 32, 35, 36, 34, 33, 31,
        28, 29, 30, 31, 30, 29, 28,
        25, 27, 29, 30, 28, 27, 26
    ]
})

px.line(data_frame=df_weather,x="Day",y="Temperature",color="City",
        hover_data=["City"],markers=True,color_discrete_sequence=["red","green","blue"])

# %%
px.

# %% [markdown]
# # 9. You are analyzing the age distribution of a population dataset.
#
# Tasks:
#
# 1. Create a DataFrame df_population containing:
#
# Age of individuals
#
# Gender (Male/Female)
#
# 2. Visualize the distribution such that:
#
# Ages are grouped into multiple equal-width intervals (moderate number of bins)
#
# The frequency of individuals in each interval is displayed
#
# Male and Female distributions are distinguished using different colors and patterns
#
# Each bar clearly shows the exact count of individuals
#
# Use a fixed pair of soft contrasting colors

# %%
import pandas as pd
import plotly.express as px


df_population = pd.DataFrame({
    "Age": [18, 22, 25, 30, 35, 40, 45, 50, 28, 32, 38, 42, 48, 26, 29, 33, 37, 41, 46, 52],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female",
               "Male", "Female", "Male", "Female", "Male", "Female",
               "Male", "Female", "Male", "Female", "Male", "Female",
               "Male", "Female"]
})

px.histogram(data_frame=df_population,x="Age",color="Gender",nbins=10,histfunc="count")

# %% [markdown]
# # 10. You are given monthly expense data categorized into different spending types.
#
# Tasks:
#
# Create a DataFrame df_expense containing:
#
# Expense categories (like Food, Rent, Travel, Shopping)
#
# Amount spent in each category
#
# Visualize the data such that:
#
# Each category is represented as a portion of a circle based on its contribution
#
# Use a set of soft, visually distinct colors
#
# The chart includes a clear title
#
# Enhance the visualization further:
#
# Display both the percentage and category name inside each slice
#
# Ensure labels are placed inside the slices
#
# Slightly separate (highlight) one important category from the rest

# %%
import pandas as pd
import plotly.express as px

df_expense = pd.DataFrame({
    "Category": ["Food", "Rent", "Travel", "Shopping"],
    "Amount": [12000, 25000, 8000, 10000]
})

fig=px.pie(data_frame=df_expense,names="Category",values="Amount")
fig.update_traces(textinfo="percent+label",textposition="inside",pull=[0.2,0,0])

# %%
df_expense = pd.DataFrame({
    "Category": ["Food", "Rent", "Travel", "Shopping"],
    "Amount": [12000, 25000, 8000, 10000]
})
pd.get_dummies(df_expense,drop_first=True)
pd.get_dummies(data=df_expense,columns=["Category"])
# Out:
#    Amount  Category_Food  Category_Rent  Category_Shopping  Category_Travel
# 0   12000           True          False              False            False
# 1   25000          False           True              False            False
# 2    8000          False          False              False             True
# 3   10000          False          False               True            False

# %% [markdown]
# # 11. You are designing a transport connectivity model between cities.
# Tasks:
#
# 1. Represent 4 cities as points in a network
#
# Define direct connections such that:
#
# City1 is connected to City2
#
# City2 connects to City3
#
# City3 connects to City4
#
# City1 also has a direct route to City4
#
# 2. Visualize the network such that:
#
# Each city name is clearly visible on the graph
#
# Nodes appear large and prominent
#
# All nodes share a uniform color theme
#
# Connections between cities are thick and clearly visible
#
# Edges have a neutral tone

# %% [markdown]
# # In a customer dataset, you have a column representing customer incomes. You want to categorize incomes into 'Low', 'Medium', and 'High' groups. Incomes below 30000 are 'Low', incomes between 30000 and 70000 are 'Medium', and incomes above 70000 are 'High'. Write a code to achieve this assuming the dataset has a column named 'income'.

# %%
df=pd.DataFrame([70000,30000,50000,60000,40000,10000,75000,55000],columns=["salary"])
df["cat"]=np.where(df.salary>70000,"high",np.where(df.salary>30000,"medium","low"))
df
# Out:
#    salary     cat
# 0   70000  medium
# 1   30000     low
# 2   50000  medium
# 3   60000  medium
# 4   40000  medium
# 5   10000     low
# 6   75000    high
# 7   55000  medium

# %%
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("diabetes_unclean.csv")
y=df[["CLASS"]]
x=df.drop("CLASS",axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape
# Out:
# (807, 13)

# %% [markdown]
# # Convert the Department column into dummy variables
#
# Keep the original DataFrame structure intact (other columns should remain unchanged)
#
# Use a prefix "Dept" for new columns
#
# Drop the original Department column
#
# Store the result in a new DataFrame df_encoded

# %% [markdown]
# ### "To upload the ‘diabetes_unclean.csv’ to your working folder
#
# 1.	Make a data frame with the variable name df

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("diabetes_unclean.csv")
df
# Out:
#        ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI CLASS
# 0     502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 1     735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6  23.0     N
# 2     420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 3     680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 4     504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4  21.0     N
# ...   ...        ...    ...   ...   ...   ...    ...   ...  ...  ...  ...   ...   ...   ...
# 1004  191     454316      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5   0.9  30.1    Y
# 1005  192     454316      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3   1.8  30.0    Y
# 1006  193     454316      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5   NaN  30.1    Y
# ...

# %% [markdown]
# ### 2.	To display the specific statistics or measures that are relevant for object-type columns

# %% [markdown]
# ### 3.	To display the specific statistics or measures that are relevant for numerical-type columns

# %% [markdown]
# ### 4.	How many rows and columns are in a given dataset

# %% [markdown]
# ### 5.	To check the missing values

# %% [markdown]
# ### 6. To replace the missing values in the column ""HbA1c"" with their mean value

# %%
df["HbA1c"] = df["HbA1c"].fillna(df["HbA1c"].mean())
df

# %% [markdown]
# ### 7.	Dropping the missing values of other columns

# %%
df=df.dropna()

# %% [markdown]
# ### 8.	Display the correlation between variables

# %% [markdown]
# ### 9.	 Checking the outliers in the dataset for the following parameters: 'AGE', 'Urea', 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI' using box plot with labels and title

# %%
import seaborn as sns

# %%
sns.boxplot(data=df[['AGE','Urea','HbA1c','Chol','TG','HDL','LDL','VLDL','BMI']])
# Out:
# <Axes: >

# %% [markdown]
# ### 10.	Visualized the ""Urea"", ""HbA1c"", ""TG"" and ""BMI"" parameters for different ages using parallel_coordinates with labels and title

# %%
df.columns
# Out:
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='str')

# %%
pd.plotting.parallel_coordinates(df,"AGE",["Urea","HbA1c","TG","BMI"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pd.plotting.parallel_coordinates(df,"AGE",[["Urea","HbA1c","TG","BMI"]])
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_misc.py:570, in parallel_coordinates(frame, class_column, cols, ax, color, use_columns, xticks, colormap, axvlines, axvlines_kwds, sort_labels, **kwargs)
#     514 """
#     515 Parallel coordinates plotting.
#     516
#    (...)
#     567     ... )  # doctest: +SKIP
#     568 """
#     569 plot_backend = _get_plot_backend("matplotlib")
# --> 570 return plot_backend.parallel_coordinates(
#     571     frame=frame,
#     572     class_column=class_column,
#     573     cols=cols,
#     574     ax=ax,
#     575     color=color,
#     576     use_columns=use_columns,
#     577     xticks=xticks,
#     578     colormap=colormap,
#     579     axvlines=axvlines,
# ...

# %% [markdown]
# ### 11.	Remove the rows whose gender column has an “f” value and give the frequency count of the “F” and “M” values in different CLASS values

# %%
df=df[df["Gender"]!="f"]

# %%
pd.crosstab(df.Gender,df.CLASS,margins=True)
# Out:
# CLASS     N  N    P    Y  Y    All
# Gender
# F        64   0  17  353   3   437
# M        38   1  36  486   9   570
# All     102   1  53  839  12  1007

# %% [markdown]
# ### 12.	Remove the outliers in the ""HbA1c"" columns and print the shape of the data frame

# %%
print(df.shape)
Q1=df.HbA1c.quantile(0.25)
Q3=df.HbA1c.quantile(0.75)
IQR=Q3-Q1
HL=Q3+1.5*IQR
LL=Q1-1.5*IQR
df=df[(df.HbA1c>=LL)&(df.HbA1c<=HL)]
print(df.shape)
# Out:
# (1007, 14)
# (998, 14)

# %% [markdown]
# # "You are given a CSV file named ipl-matches.csv, which contains data of all Indian Premier League (IPL) matches played from the year 2008 to 2022.Read the dataset and display the basic information about the DataFrame.
#
# Using Python and Pandas, write code to answer the following questions:

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Datasets/IPL_Matches_2008_2022.csv")

# %%
df
# Out:
#           ID        City        Date  ...                                       Team2Players        Umpire1         Umpire2
# 0    1312200   Ahmedabad  2022-05-29  ...  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney     Nitin Menon
# 1    1312199   Ahmedabad  2022-05-27  ...  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney     Nitin Menon
# 2    1312198     Kolkata  2022-05-25  ...  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal        MA Gough
# 3    1312197     Kolkata  2022-05-24  ...  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford       VK Sharma
# 4    1304116      Mumbai  2022-05-22  ...  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary   NA Patwardhan
# ..       ...         ...         ...  ...                                                ...            ...             ...
# ...

# %% [markdown]
# ### 1.	How many matches were won by Gujarat Titans in a Super Over ?

# %%
df.WinningTeam.unique()
# Out:
# <ArrowStringArray>
# [             'Gujarat Titans',            'Rajasthan Royals',
#  'Royal Challengers Bangalore',                'Punjab Kings',
#               'Mumbai Indians',        'Lucknow Super Giants',
#          'Sunrisers Hyderabad',              'Delhi Capitals',
#        'Kolkata Knight Riders',         'Chennai Super Kings',
#              'Kings XI Punjab',                           nan,
#             'Delhi Daredevils',      'Rising Pune Supergiant',
#                'Gujarat Lions',     'Rising Pune Supergiants',
#                'Pune Warriors',             'Deccan Chargers',
#         'Kochi Tuskers Kerala']
# Length: 19, dtype: str

# %%
df.SuperOver.unique()
# Out:
# <ArrowStringArray>
# ['N', 'Y', nan]
# Length: 3, dtype: str

# %%
df[(df["WinningTeam"]=="Gujarat Titans")&(df["SuperOver"]=="Y")]
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []

# %% [markdown]
# ### 2.	How Many Matches won by Royal Challengers Bangalore Vs Kolkata Knight Riders.

# %%
df[((df["WinningTeam"]=='Royal Challengers Bangalore')&((df["Team1"]=="Kolkata Knight Riders") | (df["Team2"]=="Kolkata Knight Riders")))]
# Out:
#           ID       City        Date  ...                                       Team2Players         Umpire1         Umpire2
# 68   1304052     Mumbai  2022-03-30  ...  ['F du Plessis', 'Anuj Rawat', 'V Kohli', 'DJ ...   J Madanagopal   Navdeep Singh
# 124  1254067    Chennai  2021-04-18  ...  ['N Rana', 'Shubman Gill', 'RA Tripathi', 'EJG...   C Shamshuddin     Nitin Menon
# 155  1216494  Abu Dhabi  2020-10-21  ...  ['D Padikkal', 'AJ Finch', 'Gurkeerat Singh', ...       VK Sharma          S Ravi
# 166  1216540        NaN  2020-10-12  ...  ['T Banton', 'Shubman Gill', 'N Rana', 'EJG Mo...  RK Illingworth    K Srinivasan
# 219  1178410    Kolkata  2019-04-19  ...  ['CA Lynn', 'SP Narine', 'Shubman Gill', 'RV U...        IJ Gould     Nitin Menon
# 385   980995    Kolkata  2016-05-16  ...  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'SR ...     CB Gaffaney  A Nand Kishore
# ...

# %%
df[((df["WinningTeam"]=='Royal Challengers Bangalore')&((df["Team1"]=="Kolkata Knight Riders") | (df["Team2"]=="Kolkata Knight Riders")))].shape[0]
# Out:
# 14

# %% [markdown]
# ### 3.	How many Matches won by Toss Winner of the Match.

# %%
df[(df["TossWinner"]==df["WinningTeam"])].shape[0]
# Out:
# 489

# %% [markdown]
# ### 4.	In how many matches was the result decided by the D/L method and the match was won by wickets?

# %%
df.WonBy.unique()
# Out:
# <ArrowStringArray>
# ['Wickets', 'Runs', 'SuperOver', 'NoResults']
# Length: 4, dtype: str

# %%
df.method.unique()
# Out:
# <ArrowStringArray>
# [nan, 'D/L']
# Length: 2, dtype: str

# %%
df[(df["method"]=="D/L")&(df["WonBy"]=="Wickets")].shape[0]
# Out:
# 8

# %% [markdown]
# ### 5.	In how many matches Toss won by Rajasthan Royals & Won the Match.

# %%
df[(df["TossWinner"]=="Rajasthan Royals")&(df["WinningTeam"]=="Rajasthan Royals")].shape[0]
# Out:
# 49

# %% [markdown]
# ### 6.	In how many matches V Kohli declared player of the match against Chennai Super Kings.

# %%
df[(df["Player_of_Match"]=="V Kohli")&((df["Team1"]=="Chennai Super Kings") | (df["Team2"]=="Chennai Super Kings"))].shape[0]
# Out:
# 2

# %% [markdown]
# ### 7.	Which Team is the Toss Winner of the Final match Played in Dubai?

# %%
df[(df["MatchNumber"]=="Final")&(df["City"]=="Dubai")]["TossWinner"]
# Out:
# 74    Kolkata Knight Riders
# Name: TossWinner, dtype: str

# %% [markdown]
# ### 8.	List out the Finals played by Kolkata Knight Riders in which Toss Won by Kolkata Knight Riders in the Finals and choose to field."

# %%
df[(df["MatchNumber"]=="Final")&(df["TossWinner"]=="Kolkata Knight Riders")&(df["TossDecision"]=="field")]
# Out:
#           ID       City        Date  ...                                       Team2Players          Umpire1         Umpire2
# 74   1254117      Dubai  2021-10-15  ...  ['Shubman Gill', 'VR Iyer', 'N Rana', 'SP Nari...      Nitin Menon  RK Illingworth
# 492   734049  Bangalore  2014-06-01  ...  ['V Sehwag', 'M Vohra', 'GJ Bailey', 'WP Saha'...  HDPK Dharmasena    BNJ Oxenford
#
# [2 rows x 20 columns]
