# %%
import requests

# %%
import json


url="https://jsonplaceholder.typicode.com/posts/1"
response = requests.get(url)
response.status_code
data = response.json()
print(json.dumps(data, indent=4))
# Out:
# {
#     "userId": 1,
#     "id": 1,
#     "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#     "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }

# %%
data={
    "userId": 1,
    "id": 1,
    "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
    "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
}
res=requests.post(url,json=data)
print(res.status_code)
res.json()
# Out:
# 404
# {}

# %%
url="http://localhost:8000/api/players/"
res=requests.get(url,verify=False)
print(res.status_code)
res.json()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\yuvra\anaconda3\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\yuvra\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\yuvra\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
# ...

# %%
data={
    "name": "Yuvraj Singh",
    # "team": "India",
    # "description": "Yuvraj Singh is a former Indian cricketer who was known for his aggressive batting style and his ability to hit sixes. He played a crucial role in India's victory in the 2011 ICC Cricket World Cup.",
    # "profile_picture": "https://upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Yuvraj_Singh_2012.jpg/220px-Yuvraj_Singh_2012.jpg",
    "runs": 15000,
    # "dob": "1981-12-06",
    # "created_at": "2024-06-01T12:00:00Z"
    "innings": 300
}
res=requests.post(url,json=data)
print(res.status_code)
res.json()
# Out:
# 401
# {'detail': 'Authentication credentials were not provided.'}

# %%
url = "http://localhost:8000/api/players/6/"
data = {
    "name": "kohli",
    "runs": 20000,
    "innings": 400
}
res = requests.put(url, json=data)
print(res.status_code)
res.json()
# Out:
# 200
# {'id': 6, 'name': 'kohli', 'runs': 20000, 'innings': 400}

# %%
url = "http://localhost:8000/api/players/6/"
data = {
    "runs": 16000,
}
res = requests.patch(url, json=data)
print(res.json())
# Out:
# {'id': 6, 'name': 'kohli', 'runs': 16000, 'innings': 400}

# %%
url = "http://localhost:8000/api/players/8/"
res = requests.delete(url)

# %%
url = "http://localhost:8000/api/players"

headers = {
    "Authorization": "Token 176f17530fdbb5308f3dbc1419100c53f4ecdaa8"
}
res = requests.get(url, headers=headers)
print(res.status_code)
res.json()
# Out:
# 200
# {'count': 6,
#  'next': 'http://localhost:8000/api/players/?page=2',
#  'previous': None,
#  'results': [{'id': 2, 'name': 'Virat Kohli', 'runs': 14000, 'innings': 300},
#   {'id': 3, 'name': 'Virat Kohli', 'runs': 14000, 'innings': 300},
#   {'id': 4, 'name': 'Virat Kohli', 'runs': 1200, 'innings': 275},
#   {'id': 5, 'name': 'koh', 'runs': 1200, 'innings': 275},
#   {'id': 6, 'name': 'kohli', 'runs': 16000, 'innings': 400}]}
