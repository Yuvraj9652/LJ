# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df=pd.read_csv("diabetes.csv")

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='str')

# %%
x=df.drop("Outcome",axis=1)
y=df["Outcome"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=SVC()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83        99
#            1       0.72      0.56      0.63        55
#
#     accuracy                           0.77       154
#    macro avg       0.75      0.72      0.73       154
# weighted avg       0.76      0.77      0.76       154
#
# [[87 12]
#  [24 31]]
# 0.7662337662337663

# %%
for i in range(1, 11):
    model=SVC(C=i)
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    print(f"C={i}, Accuracy: {accuracy_score(y_test,y_pred)}")
# Out:
# C=1, Accuracy: 0.7662337662337663
# C=2, Accuracy: 0.7727272727272727
# C=3, Accuracy: 0.7727272727272727
# C=4, Accuracy: 0.7597402597402597
# C=5, Accuracy: 0.7662337662337663
# C=6, Accuracy: 0.7597402597402597
# C=7, Accuracy: 0.7662337662337663
# C=8, Accuracy: 0.7662337662337663
# C=9, Accuracy: 0.7662337662337663
# C=10, Accuracy: 0.7662337662337663
