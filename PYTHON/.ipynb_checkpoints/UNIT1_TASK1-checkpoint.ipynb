# %% [markdown]
# ### TASK 1

# %%
import numpy as np
import pandas as pd

# %%
x=np.array(np.random.randint(1,100,(8,5)))
x
# Out:
# array([[91, 34, 15, 33, 73],
#        [47, 82, 61,  9, 49],
#        [57, 10, 25, 25, 74],
#        [31, 61, 84, 38, 96],
#        [59, 41, 41, 87, 16],
#        [80, 61, 54, 79, 26],
#        [65,  3, 91,  2, 45],
#        [82, 84, 27, 72, 89]])

# %%
df=pd.DataFrame(x,columns=['A','B','C','D','E'],index=[i for i in range(1,9)])

# %%
df
# Out:
#     A   B   C   D   E
# 1  91  34  15  33  73
# 2  47  82  61   9  49
# 3  57  10  25  25  74
# 4  31  61  84  38  96
# 5  59  41  41  87  16
# 6  80  61  54  79  26
# 7  65   3  91   2  45
# 8  82  84  27  72  89

# %%
df.shape
# Out:
# (8, 5)

# %%
df.size
# Out:
# 40

# %%
df.ndim
# Out:
# 2

# %%
df['Sum']=df['A']+df['B']+df['C']+df['D']+df['E']
df
# Out:
#     A   B   C   D   E  Sum
# 1  91  34  15  33  73  246
# 2  47  82  61   9  49  248
# 3  57  10  25  25  74  191
# 4  31  61  84  38  96  310
# 5  59  41  41  87  16  244
# 6  80  61  54  79  26  300
# 7  65   3  91   2  45  206
# 8  82  84  27  72  89  354

# %%
df.loc[6,'C']=32
df
# Out:
#     A   B   C   D   E  Sum
# 1  91  34  15  33  73  246
# 2  47  82  61   9  49  248
# 3  57  10  25  25  74  191
# 4  31  61  84  38  96  310
# 5  59  41  41  87  16  244
# 6  80  61  32  79  26  300
# 7  65   3  91   2  45  206
# 8  82  84  27  72  89  354

# %%
df.loc[2:7,'B':'D']
# Out:
#     B   C   D
# 2  82  61   9
# 3  10  25  25
# 4  61  84  38
# 5  41  41  87
# 6  61  32  79
# 7   3  91   2

# %%
df.loc[9]=[65, 5, 28, 46, 83,227]
df
# Out:
#     A   B   C   D   E  Sum
# 1  91  34  15  33  73  246
# 2  47  82  61   9  49  248
# 3  57  10  25  25  74  191
# 4  31  61  84  38  96  310
# 5  59  41  41  87  16  244
# 6  80  61  32  79  26  300
# 7  65   3  91   2  45  206
# 8  82  84  27  72  89  354
# 9  65   5  28  46  83  227

# %% [markdown]
# ### TASK 2

# %%
x=np.array(np.random.randint(1,100,(5,4)))
x
# Out:
# array([[70, 48,  9, 88],
#        [23, 29, 55, 25],
#        [74,  4, 50,  3],
#        [91, 73, 48, 59],
#        [20,  4, 97, 32]])
