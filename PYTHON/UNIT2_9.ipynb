# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("production_analysis_dataset.csv")
df
# Out:
#     production_id product_category  factory  ... machine_downtime_hr energy_consumption_kwh  profit
# 0             101       Automotive  Plant_A  ...                0.56                   1028   12286
# 1             102       Automotive  Plant_A  ...                0.32                   1038   18279
# 2             103      Electronics  Plant_A  ...                0.78                   1084   23261
# 3             104      Electronics  Plant_B  ...                1.44                   1144   11674
# 4             105        Furniture  Plant_A  ...                1.15                   1349   12045
# 5             106      Electronics  Plant_B  ...                1.12                    846   20834
# 6             107        Furniture  Plant_B  ...                1.03                   1173   12664
# 7             108      Electronics  Plant_B  ...                0.42                   1546   14010
# 8             109      Electronics  Plant_A  ...                0.62                   1586   22713
# 9             110       Automotive  Plant_B  ...                1.39                   1380   24358
# 10            111       Automotive  Plant_B  ...                0.38                   1562   19197
# 11            112        Furniture  Plant_A  ...                1.50                    941   18348
# 12            113        Furniture  Plant_C  ...                0.75                    865   16304
# 13            114        Furniture  Plant_C  ...                0.35                   1349   22302
# 14            115       Automotive  Plant_B  ...                0.20                   1539   24349
# 15            116       Automotive  Plant_A  ...                0.59                   1454   18317
# 16            117       Automotive  Plant_B  ...                1.21                   1343   10009
# 17            118      Electronics  Plant_A  ...                1.28                   1114   13923
# 18            119      Electronics  Plant_A  ...                1.47                   1345   22547
# 19            120       Automotive  Plant_C  ...                1.33                   1233   13470
# 20            121       Automotive  Plant_B  ...                1.07                   1182   17177
# 21            122      Electronics  Plant_A  ...                0.96                   1035   19641
# 22            123      Electronics  Plant_B  ...                1.32                    872   18423
# 23            124        Furniture  Plant_A  ...                1.42                   1384   19440
# 24            125        Furniture  Plant_C  ...                0.76                   1233   16735
# 25            126      Electronics  Plant_A  ...                1.24                    911   14073
# 26            127       Automotive  Plant_A  ...                0.80                    877   17260
# 27            128        Furniture  Plant_A  ...                0.83                   1018   24166
# 28            129        Furniture  Plant_C  ...                1.22                   1265   14673
# 29            130       Automotive  Plant_A  ...                1.46                   1393   22054
# 30            131      Electronics  Plant_C  ...                0.85                   1343   12579
# 31            132       Automotive  Plant_A  ...                0.51                    922   24586
# 32            133        Furniture  Plant_A  ...                0.96                   1335   15183
# 33            134        Furniture  Plant_A  ...                1.07                   1107   17491
# 34            135        Furniture  Plant_A  ...                0.48                   1071   12170
# 35            136       Automotive  Plant_C  ...                0.91                   1109   20021
# 36            137      Electronics  Plant_C  ...                0.37                    918   24577
# 37            138       Automotive  Plant_B  ...                1.13                   1008   21263
# 38            139      Electronics  Plant_B  ...                0.75                   1083   10722
# 39            140      Electronics  Plant_C  ...                0.76                    809   11832
# 40            141      Electronics  Plant_B  ...                0.37                   1115   15974
# 41            142       Automotive  Plant_A  ...                0.93                   1216   20168
# 42            143        Furniture  Plant_C  ...                1.16                   1140   22818
# 43            144        Furniture  Plant_A  ...                0.34                    839   24067
# 44            145       Automotive  Plant_A  ...                1.33                   1028   10387
# 45            146        Furniture  Plant_C  ...                0.56                   1456   18346
# 46            147      Electronics  Plant_A  ...                0.54                   1394   14349
# 47            148       Automotive  Plant_A  ...                1.48                    918   16311
# 48            149       Automotive  Plant_C  ...                1.40                   1351   21253
# 49            150        Furniture  Plant_C  ...                1.06                   1138   20209
#
# [50 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#
# File ~\anaconda3\Lib\site-packages\sklearn\__init__.py:87
#      73     # We are not importing the rest of scikit-learn during the build
#      74     # process, as it may not be compiled yet
#      75 else:
#    (...)
#      81     # later is linked to the OpenMP runtime to make it possible to introspect
#      82     # it and importing it first would fail if the OpenMP dll cannot be found.
#      83     from . import (
#      84         __check_build,  # noqa: F401
#      85         _distributor_init,  # noqa: F401
#      86     )
# ---> 87     from .base import clone
#      88     from .utils._show_versions import show_versions
#      90     __all__ = [
#      91         "calibration",
#      92         "cluster",
#    (...)
#     133         "show_versions",
#     134     ]
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils import _IS_32BIT
#      20 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      21 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\__init__.py:28
#      26 from .discovery import all_estimators
#      27 from .fixes import parse_version, threadpool_info
# ---> 28 from .murmurhash import murmurhash3_32
#      29 from .validation import (
#      30     _is_arraylike_not_scalar,
#      31     _is_pandas_df,
#    (...)
#      43     indexable,
#      44 )
#      46 # Do not deprecate parallel_backend and register_parallel_backend as they are
#      47 # needed to tune `scikit-learn` behavior and have different effect if called
#      48 # from the vendored version or or the site-package version. The other are
#      49 # utilities that are independent of scikit-learn so they are not part of
#      50 # scikit-learn public API.
#
# File sklearn\\utils\\murmurhash.pyx:1, in init sklearn.utils.murmurhash()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
import numpy as np
np.__version__
# Out:
# '2.2.6'

# %%
y= df["defective_units"]
x = df.drop("defective_units",axis = 1)

# %%
y.shape

# %%
x.shape

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
